# %%
from torchvision.datasets import ImageFolder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import cv2
import numpy as np
import pandas as pd

# %%
data = ImageFolder(root = "./add_data", transform=transforms.ToTensor())

# %%
def extract_file_names(file_list):
    file_names = []
    for file_path, _ in file_list:
        file_names.append(file_path)
    return file_names

file_names = extract_file_names(data.imgs)
len(file_names), file_names # 사진 총 181장, 파일이름 출력
# Out:
# (262,
#  ['./add_data\\mop\\1.jpg',
#   './add_data\\mop\\10.jpg',
#   './add_data\\mop\\101.jpg',
#   './add_data\\mop\\105.jpg',
#   './add_data\\mop\\112.jpg',
#   './add_data\\mop\\115.jpg',
#   './add_data\\mop\\118.jpg',
#   './add_data\\mop\\121.jpg',
#   './add_data\\mop\\134.jpg',
#   './add_data\\mop\\144.jpg',
#   './add_data\\mop\\150.jpg',
#   './add_data\\mop\\155.jpg',
#   './add_data\\mop\\157.jpg',
#   './add_data\\mop\\163.jpg',
#   './add_data\\mop\\17.jpg',
#   './add_data\\mop\\182.jpg',
#   './add_data\\mop\\184.jpg',
#   './add_data\\mop\\198.jpg',
#   './add_data\\mop\\22.jpg',
#   './add_data\\mop\\23.jpg',
#   './add_data\\mop\\24.jpg',
#   './add_data\\mop\\26.jpg',
#   './add_data\\mop\\27.jpg',
#   './add_data\\mop\\28.jpg',
#   './add_data\\mop\\29.jpg',
#   './add_data\\mop\\30.jpg',
#   './add_data\\mop\\300.jpg',
#   './add_data\\mop\\301.jpg',
#   './add_data\\mop\\302.jpg',
#   './add_data\\mop\\306.jpg',
#   './add_data\\mop\\307.jpg',
#   './add_data\\mop\\308.jpg',
#   './add_data\\mop\\310.jpg',
#   './add_data\\mop\\311.jpg',
#   './add_data\\mop\\312.jpg',
#   './add_data\\mop\\313.jpg',
#   './add_data\\mop\\314.jpg',
#   './add_data\\mop\\315.jpg',
#   './add_data\\mop\\317.jpg',
#   './add_data\\mop\\318.jpg',
#   './add_data\\mop\\319.jpg',
#   './add_data\\mop\\320.jpg',
#   './add_data\\mop\\323.jpg',
#   './add_data\\mop\\324.jpg',
#   './add_data\\mop\\325.jpg',
#   './add_data\\mop\\326.jpg',
#   './add_data\\mop\\328.jpg',
#   './add_data\\mop\\329.jpg',
#   './add_data\\mop\\330.jpg',
#   './add_data\\mop\\331.jpg',
#   './add_data\\mop\\332.jpg',
#   './add_data\\mop\\333.jpg',
#   './add_data\\mop\\335.jpg',
#   './add_data\\mop\\336.jpg',
#   './add_data\\mop\\337.jpg',
#   './add_data\\mop\\340.jpg',
#   './add_data\\mop\\342.jpg',
#   './add_data\\mop\\343.jpg',
#   './add_data\\mop\\345.jpg',
#   './add_data\\mop\\346.jpg',
#   './add_data\\mop\\347.jpg',
#   './add_data\\mop\\349.jpg',
#   './add_data\\mop\\352.jpg',
#   './add_data\\mop\\356.jpg',
#   './add_data\\mop\\357.jpg',
#   './add_data\\mop\\358.jpg',
#   './add_data\\mop\\361.jpg',
#   './add_data\\mop\\363.jpg',
#   './add_data\\mop\\366.jpg',
#   './add_data\\mop\\367.jpg',
#   './add_data\\mop\\372.jpg',
#   './add_data\\mop\\373.jpg',
#   './add_data\\mop\\375.jpg',
#   './add_data\\mop\\376.jpg',
#   './add_data\\mop\\379.jpg',
#   './add_data\\mop\\38.jpg',
#   './add_data\\mop\\380.jpg',
#   './add_data\\mop\\381.jpg',
#   './add_data\\mop\\382.jpg',
#   './add_data\\mop\\383.jpg',
#   './add_data\\mop\\385.jpg',
#   './add_data\\mop\\39.jpg',
#   './add_data\\mop\\391.jpg',
#   './add_data\\mop\\40.jpg',
#   './add_data\\mop\\45.jpg',
#   './add_data\\mop\\51.jpg',
#   './add_data\\mop\\56.jpg',
#   './add_data\\mop\\63.jpg',
#   './add_data\\mop\\64.jpg',
#   './add_data\\mop\\71.jpg',
#   './add_data\\mop\\74.jpg',
#   './add_data\\mop\\76.jpg',
#   './add_data\\mop\\82.jpg',
#   './add_data\\mop\\9.jpg',
#   './add_data\\mop _test\\10.jpg',
#   './add_data\\mop _test\\104.jpg',
#   './add_data\\mop _test\\105.jpg',
#   './add_data\\mop _test\\106.jpg',
#   './add_data\\mop _test\\108.jpg',
#   './add_data\\mop _test\\110.jpg',
#   './add_data\\mop _test\\114.jpg',
#   './add_data\\mop _test\\12.jpg',
#   './add_data\\mop _test\\120.jpg',
#   './add_data\\mop _test\\126.jpg',
#   './add_data\\mop _test\\13.jpg',
#   './add_data\\mop _test\\14.jpg',
#   './add_data\\mop _test\\15.jpg',
#   './add_data\\mop _test\\16.jpg',
#   './add_data\\mop _test\\19.jpg',
#   './add_data\\mop _test\\20.jpg',
#   './add_data\\mop _test\\22.jpg',
#   './add_data\\mop _test\\25.jpg',
#   './add_data\\mop _test\\36.jpg',
#   './add_data\\mop _test\\37.jpg',
#   './add_data\\mop _test\\39.jpg',
#   './add_data\\mop _test\\48.jpg',
#   './add_data\\mop _test\\52.jpg',
#   './add_data\\mop _test\\53.jpg',
#   './add_data\\mop _test\\59.jpg',
#   './add_data\\mop _test\\61.jpg',
#   './add_data\\mop _test\\64.jpg',
#   './add_data\\mop _test\\68.jpg',
#   './add_data\\mop _test\\76.jpg',
#   './add_data\\mop _test\\78.jpg',
#   './add_data\\mop _test\\79.jpg',
#   './add_data\\mop _test\\8.jpg',
#   './add_data\\mop _test\\85.jpg',
#   './add_data\\mop _test\\87.jpg',
#   './add_data\\mop _test\\89.jpg',
#   './add_data\\mop _test\\9.jpg',
#   './add_data\\mop _test\\92.jpg',
#   './add_data\\mop dog_test\\10.jpg',
#   './add_data\\mop dog_test\\102.jpg',
#   './add_data\\mop dog_test\\11.jpg',
#   './add_data\\mop dog_test\\138.jpg',
#   './add_data\\mop dog_test\\139.jpg',
#   './add_data\\mop dog_test\\14.jpg',
#   './add_data\\mop dog_test\\153.jpg',
#   './add_data\\mop dog_test\\185.jpg',
#   './add_data\\mop dog_test\\187.jpg',
#   './add_data\\mop dog_test\\188.jpg',
#   './add_data\\mop dog_test\\19.jpg',
#   './add_data\\mop dog_test\\196.jpg',
#   './add_data\\mop dog_test\\20.jpg',
#   './add_data\\mop dog_test\\200.jpg',
#   './add_data\\mop dog_test\\21.jpg',
#   './add_data\\mop dog_test\\22.jpg',
#   './add_data\\mop dog_test\\253.jpg',
#   './add_data\\mop dog_test\\254.jpg',
#   './add_data\\mop dog_test\\257.jpg',
#   './add_data\\mop dog_test\\26.jpg',
#   './add_data\\mop dog_test\\270.jpg',
#   './add_data\\mop dog_test\\271.jpg',
#   './add_data\\mop dog_test\\277.jpg',
#   './add_data\\mop dog_test\\294.jpg',
#   './add_data\\mop dog_test\\3.jpg',
#   './add_data\\mop dog_test\\300.jpg',
#   './add_data\\mop dog_test\\302.jpg',
#   './add_data\\mop dog_test\\305.jpg',
#   './add_data\\mop dog_test\\312.jpg',
#   './add_data\\mop dog_test\\327.jpg',
#   './add_data\\mop dog_test\\337.jpg',
#   './add_data\\mop dog_test\\34.jpg',
#   './add_data\\mop dog_test\\35.jpg',
#   './add_data\\mop dog_test\\39.jpg',
#   './add_data\\mop dog_test\\4.jpg',
#   './add_data\\mop dog_test\\40.jpg',
#   './add_data\\mop dog_test\\5.jpg',
#   './add_data\\mop dog_test\\6.jpg',
#   './add_data\\mop dog_test\\69.jpg',
#   './add_data\\mop dog_test\\70.jpg',
#   './add_data\\mop dog_test\\8.jpg',
#   './add_data\\mop dog_test\\80.jpg',
#   './add_data\\mop dog_test\\91.jpg',
#   './add_data\\mop dog_test\\95.jpg',
#   './add_data\\mop_dog\\0.jpg',
#   './add_data\\mop_dog\\12.jpg',
#   './add_data\\mop_dog\\16.jpg',
#   './add_data\\mop_dog\\19.jpg',
#   './add_data\\mop_dog\\20.jpg',
#   './add_data\\mop_dog\\201.jpg',
#   './add_data\\mop_dog\\202.jpg',
#   './add_data\\mop_dog\\21.jpg',
#   './add_data\\mop_dog\\23.jpg',
#   './add_data\\mop_dog\\230.jpg',
#   './add_data\\mop_dog\\234.jpg',
#   './add_data\\mop_dog\\24.jpg',
#   './add_data\\mop_dog\\244.jpg',
#   './add_data\\mop_dog\\25.jpg',
#   './add_data\\mop_dog\\258.jpg',
#   './add_data\\mop_dog\\26.jpg',
#   './add_data\\mop_dog\\27.jpg',
#   './add_data\\mop_dog\\281.jpg',
#   './add_data\\mop_dog\\287.jpg',
#   './add_data\\mop_dog\\299.jpg',
#   './add_data\\mop_dog\\300.jpg',
#   './add_data\\mop_dog\\302.jpg',
#   './add_data\\mop_dog\\304.jpg',
#   './add_data\\mop_dog\\305.jpg',
#   './add_data\\mop_dog\\308.jpg',
#   './add_data\\mop_dog\\309.jpg',
#   './add_data\\mop_dog\\310.jpg',
#   './add_data\\mop_dog\\311.jpg',
#   './add_data\\mop_dog\\314.jpg',
#   './add_data\\mop_dog\\315.jpg',
#   './add_data\\mop_dog\\316.jpg',
#   './add_data\\mop_dog\\319.jpg',
#   './add_data\\mop_dog\\320.jpg',
#   './add_data\\mop_dog\\321.jpg',
#   './add_data\\mop_dog\\322.jpg',
#   './add_data\\mop_dog\\33.jpg',
#   './add_data\\mop_dog\\330.jpg',
#   './add_data\\mop_dog\\331.jpg',
#   './add_data\\mop_dog\\341.jpg',
#   './add_data\\mop_dog\\342.jpg',
#   './add_data\\mop_dog\\343.jpg',
#   './add_data\\mop_dog\\344.jpg',
#   './add_data\\mop_dog\\350.jpg',
#   './add_data\\mop_dog\\351.jpg',
#   './add_data\\mop_dog\\354.jpg',
#   './add_data\\mop_dog\\358.jpg',
#   './add_data\\mop_dog\\359.jpg',
#   './add_data\\mop_dog\\36.jpg',
#   './add_data\\mop_dog\\362.jpg',
#   './add_data\\mop_dog\\37.jpg',
#   './add_data\\mop_dog\\370.jpg',
#   './add_data\\mop_dog\\371.jpg',
#   './add_data\\mop_dog\\374.jpg',
#   './add_data\\mop_dog\\375.jpg',
#   './add_data\\mop_dog\\379.jpg',
#   './add_data\\mop_dog\\38.jpg',
#   './add_data\\mop_dog\\380.jpg',
#   './add_data\\mop_dog\\381.jpg',
#   './add_data\\mop_dog\\385.jpg',
#   './add_data\\mop_dog\\387.jpg',
#   './add_data\\mop_dog\\388.jpg',
#   './add_data\\mop_dog\\39.jpg',
#   './add_data\\mop_dog\\391.jpg',
#   './add_data\\mop_dog\\392.jpg',
#   './add_data\\mop_dog\\393.jpg',
#   './add_data\\mop_dog\\394.jpg',
#   './add_data\\mop_dog\\395.jpg',
#   './add_data\\mop_dog\\41.jpg',
#   './add_data\\mop_dog\\42.jpg',
#   './add_data\\mop_dog\\44.jpg',
#   './add_data\\mop_dog\\5.jpg',
#   './add_data\\mop_dog\\52.jpg',
#   './add_data\\mop_dog\\57.jpg',
#   './add_data\\mop_dog\\62.jpg',
#   './add_data\\mop_dog\\68.jpg',
#   './add_data\\mop_dog\\7.jpg',
#   './add_data\\mop_dog\\70.jpg',
#   './add_data\\mop_dog\\74.jpg',
#   './add_data\\mop_dog\\79.jpg',
#   './add_data\\mop_dog\\84.jpg',
#   './add_data\\mop_dog\\85.jpg',
#   './add_data\\mop_dog\\87.jpg',
#   './add_data\\mop_dog\\89.jpg',
#   './add_data\\mop_dog\\9.jpg',
#   './add_data\\mop_dog\\91.jpg',
#   './add_data\\mop_dog\\92.jpg',
#   './add_data\\mop_dog\\97.jpg'])

# %%
import cv2
import numpy as np


isDragging = False                     
x0, y0, w, h = -1,-1,-1,-1              
blue, red = (255,0,0),(0,0,255)        

def onMouse(event,x,y,flags,param):    
    global isDragging, x0, y0, img      # 전역변수 참조
    if event == cv2.EVENT_LBUTTONDOWN:  # 왼쪽 마우스 버튼 다운
        isDragging = True
        x0 = x
        y0 = y
    elif event == cv2.EVENT_MOUSEMOVE:  # 마우스 움직임
        if isDragging:                  # 드래그 진행 중
            img_draw = img.copy()
            cv2.rectangle(img_draw, (x0, y0), (x, y), blue, 2) # 드래그 진행 영역 표시
            cv2.imshow('img', img_draw) # 사각형 표시된 그림 화면 출력
    elif event == cv2.EVENT_LBUTTONUP:  # 왼쪽 마우스 버튼 업
        if isDragging:                  # 드래그 중지
            isDragging = False          
            w = x - x0                  # 폭 계산
            h = y - y0                  # 높이 계산
            print("x:%d, y:%d, w:%d, h:%d" % (x0, y0, w, h))
            if w > 0 and h > 0:         # 왼쪽에서 오른쪽으로 긁었을 때, 
                img_draw = img.copy()   # 선택 영역에 사각형 그림을 표시할 이미지 복제
                # 선택 영역에 빨간 사각형 표시
                cv2.rectangle(img_draw, (x0, y0), (x, y), red, 2) 
                cv2.imshow('img', img_draw) # 빨간 사각형 그려진 이미지 화면 출력
                roi = img[y0:y0+h, x0:x0+w] # 원본 이미지에서 선택 영역만 ROI로 지정
                cv2.imshow('cropped', roi)  # ROI 지정 영역을 새창으로 표시
                cv2.moveWindow('cropped', 0, 0) # 새창을 화면 좌측 상단에 이동
                cv2.imwrite(param, roi)   # ROI 영역만 파일로 저장
                print("croped.")
            else:
                cv2.imshow('img', img)  # 드래그 방향이 잘못된 경우 사각형 그림이 없는 원본 이미지 출력
                print("좌측 상단에서 우측 하단으로 영역을 드래그 하세요.")

for i in file_names:
    try :
        img = cv2.imread(i)
        cv2.imshow('img', img)
        cv2.setMouseCallback('img', onMouse, param=i)
        cv2.waitKey()
        cv2.destroyAllWindows()
    except : # 그림이 열리지 않는 경우도 있어서, 이를 감안하여 try, catch구문 활용 
        pass
# Out:
# x:123, y:235, w:431, h:152
# croped.
# x:371, y:661, w:546, h:242
# croped.
# x:71, y:178, w:155, h:43
# croped.
# x:127, y:374, w:262, h:86
# croped.
# x:29, y:237, w:145, h:114
# croped.
# x:99, y:187, w:145, h:107
# croped.
# x:440, y:567, w:227, h:158
# croped.
# x:72, y:83, w:129, h:98
# croped.
# x:1284, y:796, w:532, h:167
# croped.
# x:98, y:73, w:105, h:54
# croped.
# x:54, y:76, w:99, h:76
# croped.
# x:347, y:368, w:365, h:310
# croped.
# x:123, y:225, w:363, h:259
# croped.
# x:563, y:427, w:584, h:462
# croped.
# x:209, y:455, w:850, h:473
# croped.
# x:153, y:227, w:304, h:200
# croped.
# x:79, y:87, w:49, h:69
# croped.
# x:236, y:474, w:237, h:33
# croped.
# x:285, y:889, w:162, h:128
# croped.
# x:104, y:136, w:146, h:120
# croped.
# x:387, y:457, w:420, h:415
# croped.
# x:292, y:453, w:440, h:457
# croped.
# x:145, y:295, w:323, h:283
# croped.
# x:121, y:218, w:231, h:154
# croped.
# x:361, y:262, w:266, h:233
# croped.
# x:189, y:603, w:183, h:286
# croped.
# x:278, y:544, w:238, h:138
# croped.
# x:229, y:355, w:221, h:126
# croped.
# x:182, y:322, w:299, h:180
# croped.
# x:174, y:336, w:101, h:117
# croped.
# x:90, y:175, w:192, h:118
# croped.
# x:222, y:377, w:164, h:93
# croped.
# x:1035, y:790, w:171, h:206
# croped.
# x:400, y:281, w:131, h:307
# croped.
# x:63, y:126, w:136, h:80
# croped.
# x:286, y:478, w:260, h:192
# croped.
# x:320, y:470, w:208, h:187
# croped.
# x:126, y:262, w:252, h:162
# croped.
# x:111, y:302, w:265, h:192
# croped.
# x:412, y:403, w:382, h:249
# croped.
# x:117, y:238, w:258, h:200
# croped.
# x:284, y:528, w:499, h:388
# croped.
# x:412, y:555, w:365, h:345
# croped.
# x:508, y:846, w:265, h:161
# croped.
# x:94, y:189, w:174, h:98
# croped.
# x:236, y:380, w:216, h:195
# croped.
# x:305, y:337, w:198, h:244
# croped.
# x:81, y:274, w:65, h:87
# croped.
# x:383, y:447, w:217, h:342
# croped.
# x:156, y:287, w:135, h:143
# croped.
# x:130, y:257, w:128, h:176
# croped.
# x:260, y:287, w:319, h:297
# croped.
# x:365, y:231, w:236, h:196
# croped.
# x:395, y:614, w:175, h:186
# croped.
# x:159, y:281, w:152, h:111
# croped.
# x:697, y:703, w:515, h:279
# croped.
# x:105, y:157, w:179, h:107
# croped.
# x:554, y:423, w:393, h:310
# croped.
# x:271, y:327, w:433, h:367
# croped.
# x:285, y:196, w:383, h:201
# croped.
# x:1084, y:690, w:563, h:229
# croped.
# x:1639, y:918, w:2, h:6
# croped.
# x:1094, y:699, w:598, h:283
# croped.
# x:495, y:185, w:253, h:315
# croped.
# x:524, y:125, w:487, h:354
# croped.
# x:96, y:89, w:129, h:156
# croped.
# x:76, y:137, w:288, h:130
# croped.
# x:336, y:390, w:301, h:215
# croped.
# x:345, y:465, w:313, h:180
# croped.
# x:619, y:682, w:715, h:353
# croped.
# x:185, y:298, w:470, h:374
# croped.
# x:126, y:245, w:207, h:198
# croped.
# x:262, y:287, w:262, h:298
# croped.
# x:164, y:323, w:284, h:189
# croped.
# x:311, y:155, w:166, h:145
# croped.
# x:360, y:398, w:273, h:246
# croped.
# x:237, y:247, w:229, h:211
# croped.
# x:370, y:311, w:237, h:221
# croped.
# x:195, y:300, w:277, h:229
# croped.
# x:1000, y:820, w:387, h:206
# croped.
# x:82, y:173, w:98, h:161
# croped.
# x:396, y:286, w:249, h:355
# croped.
# x:955, y:731, w:467, h:284
# croped.
# x:260, y:240, w:247, h:192
# croped.
# x:134, y:206, w:281, h:236
# croped.
# x:202, y:312, w:109, h:134
# croped.
# x:250, y:277, w:167, h:130
# croped.
# x:162, y:144, w:182, h:169
# croped.
# x:114, y:218, w:271, h:220
# croped.
# x:118, y:138, w:170, h:183
# croped.
# x:107, y:189, w:290, h:261
# croped.
# x:69, y:169, w:204, h:121
# croped.
# x:36, y:146, w:121, h:173
# croped.
# x:118, y:157, w:121, h:136
# croped.
# x:130, y:151, w:63, h:115
# croped.
# x:117, y:233, w:124, h:67
# croped.
# x:162, y:225, w:52, h:64
# croped.
# x:119, y:160, w:93, h:106
# croped.
# x:131, y:182, w:102, h:109
# croped.
# x:100, y:146, w:145, h:135
# croped.
# x:132, y:95, w:143, h:69
# croped.
# x:33, y:425, w:58, h:44
# croped.
# x:125, y:203, w:87, h:60
# croped.
# x:88, y:86, w:148, h:64
# croped.
# x:46, y:41, w:19, h:22
# croped.
# x:15, y:33, w:35, h:16
# croped.
# x:87, y:226, w:139, h:95
# croped.
# x:121, y:143, w:120, h:124
# croped.
# x:188, y:204, w:83, h:56
# croped.
# x:101, y:111, w:139, h:106
# croped.
# x:116, y:176, w:128, h:84
# croped.
# x:109, y:187, w:115, h:80
# croped.
# x:125, y:204, w:110, h:70
# croped.
# x:92, y:170, w:98, h:94
# croped.
# x:116, y:90, w:110, h:125
# croped.
# x:126, y:167, w:90, h:99
# croped.
# x:79, y:149, w:149, h:39
# croped.
# x:136, y:181, w:91, h:119
# croped.
# x:146, y:221, w:49, h:102
# croped.
# x:131, y:140, w:41, h:92
# croped.
# x:196, y:248, w:36, h:89
# croped.
# x:129, y:150, w:67, h:127
# croped.
# x:135, y:245, w:88, h:62
# croped.
# x:137, y:137, w:108, h:106
# croped.
# x:118, y:284, w:102, h:32
# croped.
# x:145, y:241, w:54, h:65
# croped.
# x:85, y:87, w:176, h:294
# croped.
# x:101, y:128, w:85, h:45
# croped.
# x:97, y:96, w:85, h:77
# croped.
# x:87, y:120, w:174, h:85
# croped.
# x:105, y:88, w:66, h:45
# croped.
# x:92, y:36, w:123, h:108
# croped.
# x:94, y:126, w:63, h:78
# croped.
# x:26, y:29, w:120, h:87
# croped.
# x:65, y:88, w:187, h:388
# croped.
# x:64, y:103, w:169, h:388
# croped.
# x:103, y:91, w:122, h:177
# croped.
# x:209, y:76, w:87, h:44
# croped.
# x:162, y:85, w:124, h:90
# croped.
# x:85, y:75, w:147, h:61
# croped.
# x:83, y:91, w:71, h:127
# croped.
# x:88, y:207, w:166, h:146
# croped.
# x:39, y:79, w:255, h:120
# croped.
# x:153, y:119, w:110, h:50
# croped.
# x:159, y:62, w:98, h:82
# croped.
# x:84, y:109, w:185, h:110
# croped.
# x:107, y:93, w:154, h:414
# croped.
# x:92, y:144, w:141, h:63
# croped.
# x:107, y:55, w:130, h:115
# croped.
# x:141, y:152, w:41, h:159
# croped.
# x:183, y:53, w:103, h:219
# croped.
# x:83, y:66, w:173, h:83
# croped.
# x:105, y:112, w:130, h:256
# croped.
# x:124, y:160, w:106, h:243
# croped.
# x:89, y:42, w:164, h:105
# croped.
# x:92, y:45, w:142, h:245
# croped.
# x:58, y:60, w:220, h:123
# croped.
# x:50, y:62, w:220, h:195
# croped.
# x:133, y:43, w:74, h:135
# croped.
# x:50, y:58, w:181, h:311
# croped.
# x:30, y:152, w:226, h:253
# croped.
# x:82, y:74, w:165, h:172
# croped.
# x:67, y:118, w:101, h:304
# croped.
# x:91, y:57, w:87, h:181
# croped.
# x:88, y:74, w:172, h:106
# croped.
# x:65, y:98, w:162, h:396
# croped.
# x:36, y:78, w:255, h:105
# croped.
# x:84, y:56, w:189, h:89
# croped.
# x:79, y:66, w:179, h:54
# croped.
# x:81, y:35, w:87, h:147
# croped.
# x:137, y:49, w:149, h:259
# croped.
# x:149, y:81, w:57, h:33
# croped.
# x:91, y:102, w:343, h:218
# croped.
# x:207, y:114, w:195, h:155
# croped.
# x:539, y:334, w:201, h:262
# croped.
# x:69, y:76, w:120, h:243
# croped.
# x:71, y:138, w:376, h:162
# croped.
# x:62, y:367, w:561, h:349
# croped.
# x:206, y:98, w:291, h:189
# croped.
# x:164, y:154, w:151, h:107
# croped.
# x:326, y:173, w:183, h:321
# croped.
# x:222, y:226, w:301, h:152
# croped.
# x:131, y:134, w:111, h:235
# croped.
# x:151, y:167, w:362, h:133
# croped.
# x:294, y:92, w:468, h:713
# croped.
# x:383, y:141, w:435, h:623
# croped.
# x:148, y:263, w:158, h:199
# croped.
# x:266, y:242, w:316, h:170
# croped.
# x:239, y:104, w:161, h:228
# croped.
# x:254, y:98, w:161, h:297
# croped.
# x:111, y:29, w:152, h:232
# croped.
# x:312, y:182, w:295, h:853
# croped.
# x:315, y:269, w:929, h:579
# croped.
# x:60, y:154, w:444, h:228
# croped.
# x:298, y:296, w:816, h:361
# croped.
# x:274, y:143, w:335, h:146
# croped.
# x:218, y:254, w:619, h:781
# croped.
# x:512, y:205, w:263, h:558
# croped.
# x:221, y:207, w:244, h:206
# croped.
# x:283, y:161, w:342, h:137
# croped.
# x:138, y:17, w:455, h:381
# croped.
# x:207, y:119, w:244, h:206
# croped.
# x:275, y:110, w:174, h:360
# croped.
# x:152, y:267, w:806, h:255
# croped.
# x:380, y:106, w:381, h:926
# croped.
# x:106, y:190, w:279, h:770
# croped.
# x:82, y:56, w:72, h:160
# croped.
# x:83, y:96, w:267, h:103
# croped.
# x:75, y:58, w:133, h:394
# croped.
# x:72, y:80, w:197, h:146
# croped.
# x:203, y:175, w:277, h:325
# croped.
# x:150, y:102, w:380, h:274
# croped.
# x:62, y:87, w:147, h:71
# croped.
# x:791, y:137, w:156, h:328
# croped.
# x:737, y:459, w:644, h:489
# croped.
# x:191, y:239, w:458, h:298
# croped.
# x:576, y:305, w:244, h:539
# croped.
# x:325, y:273, w:687, h:110
# croped.
# x:840, y:386, w:473, h:649
# croped.
# x:395, y:111, w:401, h:453
# croped.
# x:202, y:114, w:333, h:367
# croped.
# x:197, y:198, w:355, h:675
# croped.
# x:54, y:111, w:217, h:96
# croped.
# x:233, y:134, w:439, h:170
# croped.
# x:166, y:96, w:307, h:155
# croped.
# x:191, y:148, w:234, h:111
# croped.
# x:171, y:118, w:302, h:201
# croped.
# x:440, y:127, w:228, h:359
# croped.
# x:271, y:182, w:576, h:321
# croped.
# x:7, y:255, w:557, h:565
# croped.
# x:169, y:117, w:339, h:117
# croped.
# x:116, y:163, w:277, h:175
# croped.
# x:64, y:154, w:337, h:140
# croped.
# x:279, y:195, w:389, h:173
# croped.
# x:115, y:91, w:319, h:117
# croped.
# x:212, y:151, w:275, h:127
# croped.
# x:327, y:235, w:341, h:184
# croped.
# x:272, y:174, w:152, h:373
# croped.
# x:177, y:274, w:444, h:301
# croped.
# x:328, y:454, w:161, h:206
# croped.
# x:221, y:184, w:371, h:475
# croped.
# x:241, y:154, w:329, h:173
# croped.
# x:167, y:433, w:502, h:251
# croped.
# x:307, y:180, w:105, h:249
# croped.
# x:202, y:92, w:211, h:145
# croped.
# x:228, y:103, w:229, h:449
# croped.
# x:525, y:664, w:1094, h:369
# croped.
# x:151, y:147, w:227, h:200
# croped.
# x:247, y:139, w:430, h:783
# croped.
# x:164, y:323, w:143, h:379
# croped.
# x:32, y:62, w:120, h:396
# croped.
# x:192, y:114, w:158, h:245
# croped.
# x:78, y:593, w:391, h:150
# croped.
# x:167, y:166, w:198, h:122
# croped.
# x:203, y:251, w:347, h:143
# croped.
# x:235, y:217, w:93, h:98
# croped.
# x:410, y:222, w:668, h:749
# croped.
