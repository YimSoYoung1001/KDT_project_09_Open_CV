# %%
from torchvision.datasets import ImageFolder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import cv2
import numpy as np
import pandas as pd
# Out:
# c:\Users\mathn\.conda\envs\Torch_PY38\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] 지정된 프로시저를 찾을 수 없습니다'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
data = ImageFolder(root = "./data_test", transform=transforms.ToTensor())

# %%
def extract_file_names(file_list):
    file_names = []
    for file_path, _ in file_list:
        file_names.append(file_path)
    return file_names

file_names = extract_file_names(data.imgs)
len(file_names), file_names # 사진 총 181장, 파일이름 출력
# Out:
# (81,
#  ['./data_test\\mop _test\\10.jpg',
#   './data_test\\mop _test\\104.jpg',
#   './data_test\\mop _test\\105.jpg',
#   './data_test\\mop _test\\106.jpg',
#   './data_test\\mop _test\\108.jpg',
#   './data_test\\mop _test\\110.jpg',
#   './data_test\\mop _test\\114.jpg',
#   './data_test\\mop _test\\12.jpg',
#   './data_test\\mop _test\\120.jpg',
#   './data_test\\mop _test\\126.jpg',
#   './data_test\\mop _test\\13.jpg',
#   './data_test\\mop _test\\14.jpg',
#   './data_test\\mop _test\\15.jpg',
#   './data_test\\mop _test\\16.jpg',
#   './data_test\\mop _test\\19.jpg',
#   './data_test\\mop _test\\20.jpg',
#   './data_test\\mop _test\\22.jpg',
#   './data_test\\mop _test\\25.jpg',
#   './data_test\\mop _test\\36.jpg',
#   './data_test\\mop _test\\37.jpg',
#   './data_test\\mop _test\\39.jpg',
#   './data_test\\mop _test\\48.jpg',
#   './data_test\\mop _test\\52.jpg',
#   './data_test\\mop _test\\53.jpg',
#   './data_test\\mop _test\\59.jpg',
#   './data_test\\mop _test\\61.jpg',
#   './data_test\\mop _test\\64.jpg',
#   './data_test\\mop _test\\68.jpg',
#   './data_test\\mop _test\\76.jpg',
#   './data_test\\mop _test\\78.jpg',
#   './data_test\\mop _test\\79.jpg',
#   './data_test\\mop _test\\8.jpg',
#   './data_test\\mop _test\\85.jpg',
#   './data_test\\mop _test\\87.jpg',
#   './data_test\\mop _test\\89.jpg',
#   './data_test\\mop _test\\9.jpg',
#   './data_test\\mop _test\\92.jpg',
#   './data_test\\mop dog_test\\10.jpg',
#   './data_test\\mop dog_test\\102.jpg',
#   './data_test\\mop dog_test\\11.jpg',
#   './data_test\\mop dog_test\\138.jpg',
#   './data_test\\mop dog_test\\139.jpg',
#   './data_test\\mop dog_test\\14.jpg',
#   './data_test\\mop dog_test\\153.jpg',
#   './data_test\\mop dog_test\\185.jpg',
#   './data_test\\mop dog_test\\187.jpg',
#   './data_test\\mop dog_test\\188.jpg',
#   './data_test\\mop dog_test\\19.jpg',
#   './data_test\\mop dog_test\\196.jpg',
#   './data_test\\mop dog_test\\20.jpg',
#   './data_test\\mop dog_test\\200.jpg',
#   './data_test\\mop dog_test\\21.jpg',
#   './data_test\\mop dog_test\\22.jpg',
#   './data_test\\mop dog_test\\253.jpg',
#   './data_test\\mop dog_test\\254.jpg',
#   './data_test\\mop dog_test\\257.jpg',
#   './data_test\\mop dog_test\\26.jpg',
#   './data_test\\mop dog_test\\270.jpg',
#   './data_test\\mop dog_test\\271.jpg',
#   './data_test\\mop dog_test\\277.jpg',
#   './data_test\\mop dog_test\\294.jpg',
#   './data_test\\mop dog_test\\3.jpg',
#   './data_test\\mop dog_test\\300.jpg',
#   './data_test\\mop dog_test\\302.jpg',
#   './data_test\\mop dog_test\\305.jpg',
#   './data_test\\mop dog_test\\312.jpg',
#   './data_test\\mop dog_test\\327.jpg',
#   './data_test\\mop dog_test\\337.jpg',
#   './data_test\\mop dog_test\\34.jpg',
#   './data_test\\mop dog_test\\35.jpg',
#   './data_test\\mop dog_test\\39.jpg',
#   './data_test\\mop dog_test\\4.jpg',
#   './data_test\\mop dog_test\\40.jpg',
#   './data_test\\mop dog_test\\5.jpg',
#   './data_test\\mop dog_test\\6.jpg',
#   './data_test\\mop dog_test\\69.jpg',
#   './data_test\\mop dog_test\\70.jpg',
#   './data_test\\mop dog_test\\8.jpg',
#   './data_test\\mop dog_test\\80.jpg',
#   './data_test\\mop dog_test\\91.jpg',
#   './data_test\\mop dog_test\\95.jpg'])

# %%
import cv2
import numpy as np


isDragging = False                     
x0, y0, w, h = -1,-1,-1,-1              
blue, red = (255,0,0),(0,0,255)        

def onMouse(event,x,y,flags,param):    
    global isDragging, x0, y0, img      # 전역변수 참조
    if event == cv2.EVENT_LBUTTONDOWN:  # 왼쪽 마우스 버튼 다운
        isDragging = True
        x0 = x
        y0 = y
    elif event == cv2.EVENT_MOUSEMOVE:  # 마우스 움직임
        if isDragging:                  # 드래그 진행 중
            img_draw = img.copy()
            cv2.rectangle(img_draw, (x0, y0), (x, y), blue, 2) # 드래그 진행 영역 표시
            cv2.imshow('img', img_draw) # 사각형 표시된 그림 화면 출력
    elif event == cv2.EVENT_LBUTTONUP:  # 왼쪽 마우스 버튼 업
        if isDragging:                  # 드래그 중지
            isDragging = False          
            w = x - x0                  # 폭 계산
            h = y - y0                  # 높이 계산
            print("x:%d, y:%d, w:%d, h:%d" % (x0, y0, w, h))
            if w > 0 and h > 0:         # 왼쪽에서 오른쪽으로 긁었을 때, 
                img_draw = img.copy()   # 선택 영역에 사각형 그림을 표시할 이미지 복제
                # 선택 영역에 빨간 사각형 표시
                cv2.rectangle(img_draw, (x0, y0), (x, y), red, 2) 
                cv2.imshow('img', img_draw) # 빨간 사각형 그려진 이미지 화면 출력
                roi = img[y0:y0+h, x0:x0+w] # 원본 이미지에서 선택 영역만 ROI로 지정
                cv2.imshow('cropped', roi)  # ROI 지정 영역을 새창으로 표시
                cv2.moveWindow('cropped', 0, 0) # 새창을 화면 좌측 상단에 이동
                cv2.imwrite(param, roi)   # ROI 영역만 파일로 저장
                print("croped.")
            else:
                cv2.imshow('img', img)  # 드래그 방향이 잘못된 경우 사각형 그림이 없는 원본 이미지 출력
                print("좌측 상단에서 우측 하단으로 영역을 드래그 하세요.")

for i in file_names:
    try :
        img = cv2.imread(i)
        cv2.imshow('img', img)
        cv2.setMouseCallback('img', onMouse, param=i)
        cv2.waitKey()
        cv2.destroyAllWindows()
    except : # 그림이 열리지 않는 경우도 있어서, 이를 감안하여 try, catch구문 활용 
        pass
# Out:
# x:178, y:271, w:68, h:48
# croped.
# x:36, y:153, w:121, h:152
# croped.
# x:113, y:178, w:124, h:98
# croped.
# x:124, y:184, w:77, h:68
# croped.
# x:149, y:231, w:53, h:35
# croped.
# x:178, y:239, w:73, h:66
# croped.
# x:119, y:165, w:93, h:101
# croped.
# x:117, y:182, w:107, h:81
# croped.
# x:96, y:128, w:146, h:154
# croped.
# x:152, y:105, w:80, h:67
# croped.
# x:38, y:426, w:52, h:55
# croped.
# x:128, y:183, w:79, h:124
# croped.
# x:179, y:132, w:68, h:49
# croped.
# x:48, y:48, w:16, h:16
# croped.
# x:12, y:32, w:30, h:18
# croped.
# x:133, y:232, w:67, h:53
# croped.
# x:131, y:151, w:112, h:121
# croped.
# x:183, y:200, w:79, h:66
# croped.
# x:102, y:136, w:142, h:104
# croped.
# x:95, y:171, w:118, h:65
# croped.
# x:111, y:185, w:104, h:86
# croped.
# x:121, y:206, w:117, h:73
# croped.
# x:85, y:172, w:97, h:94
# croped.
# x:103, y:113, w:119, h:93
# croped.
# x:123, y:185, w:93, h:85
# croped.
# x:76, y:150, w:89, h:66
# croped.
# x:136, y:168, w:88, h:81
# croped.
# x:138, y:247, w:58, h:63
# croped.
# x:128, y:155, w:49, h:75
# croped.
# x:187, y:260, w:42, h:67
# croped.
# x:123, y:167, w:73, h:104
# croped.
# x:131, y:237, w:76, h:41
# croped.
# x:131, y:140, w:121, h:92
# croped.
# x:123, y:292, w:89, h:31
# croped.
# x:142, y:250, w:63, h:56
# croped.
# x:77, y:133, w:200, h:258
# croped.
# x:112, y:132, w:74, h:37
# croped.
# x:98, y:88, w:81, h:65
# croped.
# x:106, y:121, w:141, h:75
# croped.
# x:107, y:89, w:50, h:38
# croped.
# x:84, y:45, w:121, h:63
# croped.
# x:91, y:130, w:71, h:79
# croped.
# x:43, y:57, w:85, h:54
# croped.
# x:60, y:137, w:149, h:171
# croped.
# x:73, y:219, w:184, h:180
# croped.
# x:95, y:178, w:108, h:81
# croped.
# x:210, y:72, w:54, h:51
# croped.
# x:181, y:89, w:99, h:87
# croped.
# x:120, y:81, w:98, h:63
# croped.
# x:86, y:129, w:71, h:80
# croped.
# x:96, y:279, w:87, h:97
# croped.
# x:207, y:77, w:76, h:88
# croped.
# x:155, y:114, w:77, h:50
# croped.
# x:179, y:72, w:70, h:82
# croped.
# x:103, y:108, w:116, h:108
# croped.
# x:61, y:318, w:142, h:152
# croped.
# x:85, y:171, w:58, h:77
# croped.
# x:180, y:62, w:72, h:85
# croped.
# x:107, y:256, w:87, h:49
# croped.
# x:65, y:152, w:207, h:104
# croped.
# x:112, y:106, w:79, h:54
# croped.
# x:106, y:235, w:125, h:123
# croped.
# x:115, y:265, w:140, h:113
# croped.
# x:91, y:56, w:116, h:99
# croped.
# x:109, y:182, w:162, h:95
# croped.
# x:100, y:71, w:107, h:110
# croped.
# x:49, y:87, w:126, h:150
# croped.
# x:139, y:110, w:69, h:71
# croped.
# x:86, y:33, w:107, h:120
# croped.
# x:55, y:264, w:102, h:124
# croped.
# x:74, y:101, w:90, h:123
# croped.
# x:194, y:176, w:102, h:115
# croped.
# x:153, y:129, w:80, h:72
# croped.
# x:164, y:84, w:90, h:84
# croped.
# x:88, y:238, w:144, h:162
# croped.
# x:171, y:94, w:105, h:98
# croped.
# x:153, y:64, w:109, h:84
# croped.
# x:174, y:67, w:60, h:64
# croped.
# x:58, y:112, w:96, h:74
# croped.
# x:106, y:192, w:94, h:116
# croped.
# x:155, y:80, w:47, h:37
# croped.
